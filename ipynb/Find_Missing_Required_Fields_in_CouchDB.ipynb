# %%
from __future__ import print_function

# %%
import couchdb
s=couchdb.Server('https://54.84.142.143/couchdb')
db=s['ucldc']

# %%
def get_missing_for_field(field_path):
    viewname = 'qa_reports/{0}_value'.format(field_path)
    view=db.view(viewname, startkey='["__MISSING__"]', endkey=["__MISSING__", {}],group_level=3)
    try:
        missing_list = [r for r in view]
    except couchdb.ResourceNotFound:
        missing_list = ['view not found for {0}'.format(viewname)]
    return missing_list

# %%
#NOTE: this step will take some time to run, as it does a lot of queires agains the couchdb
fields_to_check = ["sourceResource.specType",
"isShownAt",
"isShownBy",
"sourceResource.title",
"sourceResource.creator",
"sourceResource.publisher",
"sourceResource.date",
"sourceResource.description",
"sourceResource.format",
"sourceResource.type",
"sourceResource.subject.name",
"sourceResource.spatial.state",
"sourceResource.spatial.name",
"sourceResource.stateLocatedIn.name",
"sourceResource.rights",
"provider.name",
"intermediateProvider",
"dataProvider",
"sourceResource.collection.title",
"sourceResource.collection.description",
"sourceResource.contributor",
"sourceResource.language.name",
"sourceResource.language.iso639_3",
"sourceResource.temporal",
"sourceResource.isPartOf",
"sourceResource.relation",
"sourceResource.extent",
"sourceResource.identifier",
]

missing = {}
for field in fields_to_check:
    missing[field] = get_missing_for_field(field)

# %%
for fieldpath, rows in missing.items():
    print('{0}:{1}\n'.format(fieldpath, len(rows)))
# Out:
# sourceResource.collection.description:41180
#
# sourceResource.isPartOf:41180
#
# sourceResource.extent:41180
#
# sourceResource.language.name:23120
#
# sourceResource.collection.title:0
#
# sourceResource.creator:22460
#
# sourceResource.type:1495
#
# sourceResource.spatial.name:41180
#
# isShownBy:54
#
# dataProvider:0
#
# sourceResource.spatial.state:41180
#
# provider.name:41180
#
# sourceResource.relation:660
#
# sourceResource.stateLocatedIn.name:0
#
# sourceResource.identifier:0
#
# sourceResource.language.iso639_3:23120
#
# intermediateProvider:41180
#
# sourceResource.temporal:41180
#
# sourceResource.date:16043
#
# sourceResource.publisher:7999
#
# isShownAt:964
#
# sourceResource.title:281
#
# sourceResource.subject.name:0
#
# sourceResource.contributor:34396
#
# sourceResource.specType:41180
#
# sourceResource.format:10690
#
# sourceResource.description:17132
#
# sourceResource.rights:15313

# %%
#now flag problems, there are certain items that should never be missing

import sys
def report_missing_for_field(field, missing=None):
    if not missing:
        missing = get_missing_for_field(field)
    for row in missing:
        print('Missing {0}: {1}'.format(field, row['key'][2]), file=sys.stderr)

# %%
report_missing_for_field('dataProvider', missing=missing['dataProvider'])

# %%
report_missing_for_field('sourceResource.identifier', missing=missing['sourceResource.identifier'])

# %%
report_missing_for_field('sourceResource.title')
# Out:
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf000003vd
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf009nb0vq
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf009nb0w7
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf009nb0xr
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf038nb140
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf0489n7wh
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf058004kh
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf058004m1
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf067nb155
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf0779n81q
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf087004wt
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf096nb0r4
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf0b69n7ts
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf0c600464
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf0d5nb0zw
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf0d5nb10w
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf0d5nb11d
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf0d5nb13f
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf0f59n7d7
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf0g500526
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf0g500547
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf0k400490
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf0m3nb1fx
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf0q2nb11c
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf0r29n7hr
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf0s20055q
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf0t1nb1nb
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf0x0nb1fw
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf0x0nb1hx
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf0x0nb1jf
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf109nb134
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf1199n8q2
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf1199n8rk
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf1199n8wn
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf1489n8xt
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf1489n8zb
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf1489n91v
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf158004zh
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf1779n86m
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf196nb1c7
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf1c6004ws
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf1d5nb1hz
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf1f59n8qp
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf1f59n8t7
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf1f59n8vr
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf1f59n8xs
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf1g500510
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf1h4nb1m5
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf1m3nb1dq
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/t
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf9x0nb7hm
# Missing sourceResource.title: 13655--http://ark.cdlib.org/ark:/13030/tf9z09p45p
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf0779p1k2
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf0d5nb4q6
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf0h4nb442
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf0n39p15g
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf138nb526
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf158008cn
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf158008d5
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf1779p1ds
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf1x0nb571
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf1z09p215
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf3489p3h8
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf3f59p284
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf3r29p2xx
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf3v19p3x2
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf4d5nb764
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf4h4nb70p
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf4n39p3v1
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf5f59p5sz
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf5m3nb7xm
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf5v19p47t
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf5z09p4kn
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf5z09p4m5
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf687011mj
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf6c6011ck
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf6d5nb85q
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf6n39p5qj
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf758011r8
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf7x0nc0bg
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf8b69p6m4
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf8g50135q
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf8m3nb912
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf8m3nb92k
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf8v19p6md
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf8x0nc0sh
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf909nb9nr
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf9b69p6jd
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf9g501482
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf9p30143s
# Missing sourceResource.title: 3381--http://ark.cdlib.org/ark:/13030/tf9z09p7dr
